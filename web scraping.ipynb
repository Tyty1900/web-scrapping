# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_highest_mountains_on_Earth'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
tables = soup.find_all('table', class_='wikitable sortable')

# %%
data = []

# %%
for table in tables:
    
    headers = [header.get_text(strip=True) for header in table.find_all('th')]
    
   
    rows = table.find_all('tr')
    
    
    if headers:
        for row in rows[1:]:  
            columns = row.find_all('td')
            row_data = [col.get_text(strip=True) for col in columns]
            data.append(row_data)

# %%
df = pd.DataFrame(data, columns=headers)

# %%
print(df)
# Out:
#     Rank[i]                    Mountain name(s)          Height(rounded)[ii]  \
# 0         1  Mount EverestSagarmathaChomolungma  8,849 metres (29,032 ft)[a]
# 1         2                                  K2     8,611 metres (28,251 ft)
# 2         3                       Kangchenjunga     8,586 metres (28,169 ft)
# 3         4                              Lhotse     8,516 metres (27,940 ft)
# 4         5                              Makalu     8,485 metres (27,838 ft)
# ..      ...                                 ...                          ...
# 115     104           Noijin KangsangNorin Kang     7,206 metres (23,642 ft)
# 116     105                         Langtang Ri     7,205 metres (23,638 ft)
# 117     106             Kangphu KangShimokangri     7,204 metres (23,635 ft)
# 118     107                       Singhi Kangri     7,202 metres (23,629 ft)
# 119     108                         Lupghar Sar     7,200 metres (23,600 ft)
#
# ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
headers = [header.get_text(strip=True) for header in table.find_all('th')]

# %%
rows = table.find_all('tr')

# %%
df = pd.DataFrame(data, columns=headers)

# %%
df
# Out:
#     Rank[i]                    Mountain name(s)          Height(rounded)[ii]  \
# 0         1  Mount EverestSagarmathaChomolungma  8,849 metres (29,032 ft)[a]
# 1         2                                  K2     8,611 metres (28,251 ft)
# 2         3                       Kangchenjunga     8,586 metres (28,169 ft)
# 3         4                              Lhotse     8,516 metres (27,940 ft)
# 4         5                              Makalu     8,485 metres (27,838 ft)
# ..      ...                                 ...                          ...
# 115     104           Noijin KangsangNorin Kang     7,206 metres (23,642 ft)
# 116     105                         Langtang Ri     7,205 metres (23,638 ft)
# 117     106             Kangphu KangShimokangri     7,204 metres (23,635 ft)
# 118     107                       Singhi Kangri     7,202 metres (23,629 ft)
# 119     108                         Lupghar Sar     7,200 metres (23,600 ft)
#
# ...

# %%
df.to_csv(r'D:\ML\projects\web scraping\tallestmountaintable.csv', index=False)

# %%
# df.to_csv('D:/ML/projects/web scraping/tallestmountaintable.csv', index=False)
